# %%
import nbimporter
import db_configuration as db_config

# Teste se funcionou chamando uma classe
print(db_config.DBConnection)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 2
#       1 import nbimporter
# ----> 2 import db_configuration as db_config
#       3
#       4 # Teste se funcionou chamando uma classe
#       5 print(db_config.DBConnection)
#
# ModuleNotFoundError: No module named 'db_configuration'
